# %%
#import
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# !pip install konlpy
# !pip install wordcloud
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 874 kB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (453 kB)
#      |████████████████████████████████| 453 kB 65.8 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (4.2.0)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.0 konlpy-0.6.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from wordcloud) (7.1.2)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from wordcloud) (1.21.6)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
import numpy as np

# %%
#한글 폰트 설치
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 0s (38.4 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 155632 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
#한글 폰트 설정
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %%
#우즈베키스탄
UZB = pd.read_csv('한국산업인력공단_외국인근로자가 자주 쓰는 외국어(우즈베키스탄).csv', encoding='cp949')
UZB

#한국어 문장만 추출
UZB_korean = UZB['한국어_문장']
UZB_korean

#csv파일로 저장
UZB_korean.to_csv('UZB_korean.txt')

#우즈베키스탄_단어추출
with open('UZB_korean.txt', 'r', encoding='utf-8') as f:
    text_UZB = f.read()

okt = Okt()
nouns = okt.nouns(text_UZB) # 명사만 추출

words_UZB = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c_UZB = Counter(words_UZB) # 위에서 얻은 words를 처리하여 단어별 빈도수 형태의 딕셔너리 데이터를 구함
c_UZB

#한글로 워드클라우드 시각화
wc = WordCloud(font_path='NanumBarunGothic', background_color='white', width=400, height=400, scale=2.0, max_font_size=250)
cloud_UZB = wc.generate_from_frequencies(c_UZB)
plt.figure()
plt.imshow(cloud_UZB)

#파일로 저장하기
wc.to_file('우즈베키스탄_워드클라우드.png')

#사진 모양대로 워드클라우드 만들기
img = Image.open('우즈베키스탄_지도.png')
img_array = np.array(img)

wc = WordCloud(font_path='NanumBarunGothic', background_color='white', width=400, height=400, scale=2.0, max_font_size=250, mask=img_array)
gen = wc.generate_from_frequencies(c_UZB)

plt.figure()
plt.imshow(gen)

#파일로 저장하기
wc.to_file('우즈베키스탄_워드클라우드_국가모양.png')

# %%
#인도네시아
INA = pd.read_csv('한국산업인력공단_외국인근로자가 자주 쓰는 외국어(인도네시아).csv', encoding='cp949')
INA

#한국어 문장만 추출
INA_korean = INA['한국어_문장']
INA_korean

#csv파일로 저장
INA_korean.to_csv('INA_korean.txt')

#우즈베키스탄_단어추출
with open('INA_korean.txt', 'r', encoding='utf-8') as f:
    text_INA = f.read()

okt = Okt()
nouns = okt.nouns(text_INA) # 명사만 추출

words_INA = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c_INA = Counter(words_INA) # 위에서 얻은 words를 처리하여 단어별 빈도수 형태의 딕셔너리 데이터를 구함
c_INA

#한글로 워드클라우드 시각화
wc = WordCloud(font_path='NanumBarunGothic', background_color='white', width=400, height=400, scale=2.0, max_font_size=250)
cloud_INA = wc.generate_from_frequencies(c_INA)
plt.figure()
plt.imshow(cloud_INA)

#파일로 저장하기
wc.to_file('인도네시아_워드클라우드.png')

#사진 모양대로 워드클라우드 만들기
img = Image.open('인도네시아_지도.png')
img_array = np.array(img)

wc = WordCloud(font_path='NanumBarunGothic', background_color='white', width=400, height=400, scale=2.0, max_font_size=250, mask=img_array)
gen = wc.generate_from_frequencies(c_INA)
plt.figure()
plt.imshow(gen)

#파일로 저장하기
wc.to_file('인도네시아_워드클라우드_국가모양.png')

# %%
#중국
CHN = pd.read_csv('한국산업인력공단_외국인근로자가 자주 쓰는 외국어(중국).csv', encoding='cp949')
CHN

#한국어 문장만 추출
CHN_korean = CHN['한국어']
CHN_korean

#csv파일로 저장
CHN_korean.to_csv('CHN_korean.txt')

#우즈베키스탄_단어추출
with open('CHN_korean.txt', 'r', encoding='utf-8') as f:
    text_CHN = f.read()

okt = Okt()
nouns = okt.nouns(text_CHN) # 명사만 추출

words = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c_CHN = Counter(words) # 위에서 얻은 words를 처리하여 단어별 빈도수 형태의 딕셔너리 데이터를 구함
c_CHN

#한글로 워드클라우드 시각화
wc = WordCloud(font_path='NanumBarunGothic', background_color='white', width=400, height=400, scale=2.0, max_font_size=250)
cloud_CHN = wc.generate_from_frequencies(c_CHN)
plt.figure()
plt.imshow(cloud_CHN)

#파일로 저장하기
wc.to_file('중국_워드클라우드.png')

#사진 모양대로 워드클라우드 만들기
img = Image.open('중국_지도.png')
img_array = np.array(img)

wc = WordCloud(font_path='NanumBarunGothic', background_color='white', width=400, height=400, scale=2.0, max_font_size=250, mask=img_array)
gen = wc.generate_from_frequencies(c_CHN)

plt.figure()
plt.imshow(gen)

#파일로 저장하기
wc.to_file('중국_워드클라우드_국가모양.png')

# %%
#키르기스스탄
KGZ = pd.read_csv('한국산업인력공단_외국인근로자가 자주 쓰는 외국어(키르기스스탄).csv', encoding='cp949')
KGZ

#한국어 문장만 추출
KGZ_korean = KGZ['한국어']
KGZ_korean

#csv파일로 저장
KGZ_korean.to_csv('KGZ_korean.txt')

#우즈베키스탄_단어추출
with open('KGZ_korean.txt', 'r', encoding='utf-8') as f:
    text_KGZ = f.read()

okt = Okt()
nouns = okt.nouns(text_KGZ) # 명사만 추출

words = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c_KGZ = Counter(words) # 위에서 얻은 words를 처리하여 단어별 빈도수 형태의 딕셔너리 데이터를 구함
c_KGZ

#한글로 워드클라우드 시각화
wc = WordCloud(font_path='NanumBarunGothic', background_color='white', width=400, height=400, scale=2.0, max_font_size=250)
cloud_KGZ = wc.generate_from_frequencies(c_KGZ)
plt.figure()
plt.imshow(cloud_KGZ)

#파일로 저장하기
wc.to_file('키르기스스탄_워드클라우드.png')

#사진 모양대로 워드클라우드 만들기
img = Image.open('키르기스스탄_지도.png')
img_array = np.array(img)

wc = WordCloud(font_path='NanumBarunGothic', background_color='white', width=400, height=400, scale=2.0, max_font_size=250, mask=img_array)
gen = wc.generate_from_frequencies(c_KGZ)

plt.figure()
plt.imshow(gen)

#파일로 저장하기
wc.to_file('키르기스스탄_워드클라우드_국가모양.png')

# %%
#필리핀
PHI = pd.read_csv('한국산업인력공단_외국인근로자가 자주 쓰는 외국어(필리핀).csv', encoding='cp949')
PHI

#한국어 문장만 추출
PHI_korean = PHI['한국어 문장']
PHI_korean

#csv파일로 저장
PHI_korean.to_csv('PHI_korean.txt')

#우즈베키스탄_단어추출
with open('PHI_korean.txt', 'r', encoding='utf-8') as f:
    text_PHI = f.read()

okt = Okt()
nouns = okt.nouns(text_PHI) # 명사만 추출

words = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c_PHI = Counter(words) # 위에서 얻은 words를 처리하여 단어별 빈도수 형태의 딕셔너리 데이터를 구함
c_PHI

#한글로 워드클라우드 시각화
wc = WordCloud(font_path='NanumBarunGothic', background_color='white', width=400, height=400, scale=2.0, max_font_size=250)
cloud_PHI = wc.generate_from_frequencies(c_PHI)
plt.figure()
plt.imshow(cloud_PHI)

#파일로 저장하기
wc.to_file('필리핀_워드클라우드.png')

#사진 모양대로 워드클라우드 만들기
img = Image.open('필리핀_지도.png')
img_array = np.array(img)

wc = WordCloud(font_path='NanumBarunGothic', background_color='white', width=400, height=400, scale=2.0, max_font_size=250, mask=img_array)
gen = wc.generate_from_frequencies(c_PHI)

plt.figure()
plt.imshow(gen)

#파일로 저장하기
wc.to_file('필리핀_워드클라우드_국가모양.png')
